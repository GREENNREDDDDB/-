# %% [markdown]
# # 一、YOLOv1
# https://zhuanlan.zhihu.com/p/364367221
#
# ## 1、网络架构
# ![image.png](attachment:image.png)
#
# ## 2、检测原理
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# ## 3、YOLOv1的正样本(训练的标签)制作方法与物体中心点的确定

# %% [markdown]
# # 二、改进YOLOv1(改进backbon neck head prediction)
# https://zhuanlan.zhihu.com/p/364912692

# %% [markdown]
# # YOLO 映射出坐标
# https://www.zhihu.com/question/445546731
# https://blog.csdn.net/weixin_44612221/article/details/115384742

# %% [markdown]
# # YOLOv4 解读1
# https://www.cnblogs.com/further-further-further/p/14115515.html

# %% [markdown]
# # YOLOv4 in Jetson NANO
# https://blog.csdn.net/FriendshipTang/article/details/109863645
# https://zhuanlan.zhihu.com/p/429220165
